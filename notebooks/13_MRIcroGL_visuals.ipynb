# %% [markdown]
# # Brainmap visualizations in MRIcroGL
#
# This notebook only describes where to find the scripts to reproduce the brainmap visualizations in MRIcroGL. For more information on how to use these scripts and general instructions about this program, please refer to the [MRIcroGL documentation](https://github.com/rordenlab/MRIcroGL).
#
# All necessary scripts to reproduce the brainmap visualizations in MRIcroGL are available in the `source_code/MRIcroGL_visuals` folder of this repository. You can find them [here](../source_code/MRIcroGL_visuals).
